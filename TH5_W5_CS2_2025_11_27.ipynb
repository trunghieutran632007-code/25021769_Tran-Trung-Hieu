# %%
#W5A1
check = False
while check == False:
  try:
    a,b = map(int,input().split())

    def Max_Of_Two(a,b):
      print(max(a,b))
    Max_Of_Two(a,b)
    check = True
  except ValueError:
    print("Gia tri khong hop le")
# Out:
# a b
# Gia tri khong hop le
# a c
# Gia tri khong hop le
# 1 2
# 2

# %%
#W5A2
def swap(a,b):
  return b,a
check = False
while check == False:
  try:
    a,b = map(int,input().split())
    a,b = swap(a,b)
    print(a,b)
    check = True
  except ValueError:
    print("Gia tri khong hop le")
# Out:
# a s
# Gia tri khong hop le
# da d
# Gia tri khong hop le
# dada
# Gia tri khong hop le
# 2 3
# 3 2

# %%
#W5A3
def primeNum(a):
  for i in range(2, int(a**0.5)+1):
    if a%i == 0:
      return False
    return True

a = int(input())
if primeNum(a):
  print("YES")
else:
  print("NO")
# Out:
# 4
# NO

# %%
#W5A4
def perfectNum(a):
    if a <= 1:
        print("No")
        return

    s = 1
    for i in range(2, int(a**0.5) + 1):
        if a % i == 0:
            s += i
            if i != a // i:
                s += a // i

    if s == a:
        print("Yes")
    else:
        print("No")

n = int(input())
perfectNum(n)
# Out:
# 6
# Yes

# %%
#W5A5
def findNum(a, x):
  for i in range(0, len(a)):
    if x == a[i]:
      return i+1
  return -1
a = list(map(int, input().split()))
k = int(input('Nhap so k: '))
print(findNum(a, k))
# Out:
# 2 3 4 5 6
# Nhap so k: 6
# 5

# %%
#W5A6
def giaithua(n):
  ans = 1
  for i in range(1,n+1):
    ans = ans*i
  return ans
n = int(input())
print(f'n giai thua la {giaithua(n)}')
# Out:
# 5
# n giai thua la 120

# %%
#W5A7
def calculate(a,b):
  sum = a+b
  tich = a*b
  thuong = a/b #fix
  hieu = a-b
  print(f'tong: {round(sum)}\n hieu: {round(hieu)}\n tich: {round(tich)}\n thuong: {round(thuong)}')

a,b = map(int, input().split())
calculate(a,b)
# Out:
# 10 3
# tong: 13
#  hieu: 7
#  tich: 30
#  thuong: 3

# %%
#W5A8
def xor2So(a,b):
  return a ^ b
def demSoBit1(a):
  count = 0
  while a!=0:
    if a%2 == 1:
      count = count + 1
    a = a//2
  return count
a,b = map(int, input().split())
print(f"Khoang cach Hamming la: {demSoBit1(xor2So(a,b))}")
# Out:
# 11 9
# Khoang cach Hamming la: 1

# %%
#W5A9
def TongCacChuSo(n):
  sum = 0
  for i in range (len(n)):
    sum = sum + int(n[i])
  return sum

n = input()
print(TongCacChuSo(n))
# Out:
# 456
# 15

# %%
#W5A10
def isIsomorphic(a, b):
    # Tao mang luu hieu ascii cho tung ky tu
    diff = {}

    for i in range(len(a)):
        c1 = a[i]
        c2 = b[i]
        d = ord(c1) - ord(c2)

        # Neu ky tu da xuat hien truoc do
        if c1 in diff:
            # Kiem tra hieu co giong lan truoc khong
            if diff[c1] != d:
                return False
        else:
            diff[c1] = d

    # Kiem tra xem co 2 ky tu khac nhau cua a cung anh xa vao 1 ky tu cua b hay khong
    # Neu 2 hieu khac nhau trung mot hieu voi cac ky tu khac nhau thi khong hop le
    # (dam bao tinh 1-1)
    if len(set(diff.values())) != len(diff):
        return False

    return True
a = input()
b = input()
if isIsomorphic(a,b ):
  print("Dang cau")
else:
  print("Khong dang cau")
# Out:
# adszcx
# bmnhkj
# Dang cau
