# %%
#W2A1
print("Hello World")
# Out:
# Hello World

# %%
#W2A2
name = input()
print(f'Hello {name}')
# Out:
# Tran Trung Hieu
# Hello Tran Trung Hieu

# %%
#W2A3
a, b = map(int, input().split())
print(f'{a} + {b} = {a+b}')
print(f'{a} - {b} = {a-b}')
print(f'{a} * {b} = {a*b}')
print(f'{a} / {b} = {a/b:.2f}')
print(f'{a} // {b} = {a//b}')
# Out:
# 4 + 2 = 6
# 4 - 2 = 2
# 4 * 2 = 8
# 4 / 2 = 2.00
# 4 // 2 = 2

# %%
#W2A4
a1, b1, c1, a2, b2, a3 = map(int, input().split())
Tb = (a1 + b1 + c1 + (a2 +b2)*2 + a3 * 3)/10
print(f'{Tb:.1f}')
# Out:
# 8.9

# %%
#W2A5
a, b = map(int, input().split())
print(f'{a**b}')
# Out:
# 2 4
# 16

# %%
#W2A6
s2 = input()
s2 = ord(s2) - 32
print(chr(s2))
# Out:
# a
# A

# %%
#W2A7
a = ((13 ** 2) * 3) + 5
b = 13**2*3 + 5
print(a)
print(b)
# Out:
# 512
# 512

# %%
#W2A8
t = int(input("Bạn hãy nhập nhiệt độ theo thang Celcius: "))
f = t * 1.8 + 32
print(f'Nhiệt độ theo thang Fahrenheit là: {f:.2f}')
# Out:
# Bạn hãy nhập nhiệt độ theo thang Celcius: 10
# Nhiệt độ theo thang Fahrenheit là: 50.00

# %%
#W2A9
x = int(input("Bạn hãy nhập giá của đồng hồ: "))
finalPrice = x*1.4 + 10 #x + 0.3*x + 0.4*x + 10
print(f'Tổng số tiền cần trả là: {finalPrice} $')
# Out:
# Bạn hãy nhập giá của đồng hồ: 50
# Tổng số tiền cần trả là: 80.0 $

# %%
#W2A10
name1, name2, name3 = input().split()
print(f'Hello {name3},{name2} and {name1}')
# Out:
# John Yuki Verstappen
# Hello Verstappen,Yuki and John

# %%
#W2A11
hours, mins = map(int, input("Nhập lần lượt số giờ và số phút: ").split())
secs = hours * 3600 + mins * 60
print(f'Tổng số giây là: {secs}')
# Out:
# Nhập lần lượt số giờ và số phút: 1 30
# Tổng số giây là: 5400

# %%
#W2A12
n = int(input("Nhập độ dài của Rubik: "))
x = n**2 * 6
print(f'Tổng số miếng dán là: {x}')
# Out:
# Nhập độ dài của Rubik: 3
# Tổng số miếng dán là: 54

# %%
#W2A13
a ,b = map(int, input("Nhập 2 số: ").split())
x = a*b
c = x%10
print(f'Chũ số hàng đơn vị của tích là: {c}')
# Out:
# Nhập 2 số: 4 6
# Chũ số hàng đơn vị của tích là: 4

# %%
#W2A14
a = int(input("Nhập số a: "))
b = int(input("Nhập số b: "))
a = a + b
b = a - b
a = a - b
print(f'Số a lúc sau là: {a}')
print(f'Số b lúc sau là: {b}')
# Out:
# Nhập số a: 16
# Nhập số b: 21
# Số a lúc sau là: 21
# Số b lúc sau là: 16

# %%
#W2A15
# Công thức số sao:S(n)=6n(n−1)+1
n = int(input("Nhập số: "))
s = 6*n*(n-1) + 1
print(f'Số sao thứ n là: {s}')
# Out:
# Nhập số: 6
# Số sao thứ n là: 181

# %%
#W2A16
print("Spring")
print("Summer")
print("Autumn")
print("Winter")
# Out:
# Spring
# Summer
# Autumn
# Winter

# %%
#W2A17
print("*")
print("***")
print("*****")
# Out:
# *
# ***
# *****

# %%
#W2A18
print("###   ##   ### ###")
print(" #    # #   #   #")
print(" #    #  #  #   #")
print(" #    # #   #   #")
print(" #    ##    #   #")
# Out:
# ###   ##   ### ###
#  #    # #   #   #
#  #    #  #  #   #
#  #    # #   #   #
#  #    ##    #   #

# %%
#W2A19
print("Monday\nTuesday\nWednesday\nThursday\nFriday\nSaturday\nSunday")
# Out:
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday

# %%
#W2A20
print("January\nFebruary\nMarch\nApril\nMay\nJune\nJuly\nAugust\nSeptember\nOctober\nNovember\nDecember")
# Out:
# January
# February
# March
# April
# May
# June
# July
# August
# September
# October
# November
# December

# %%
#W2A21
for i in range(10):
  print("Hello, world")
# Out:
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
