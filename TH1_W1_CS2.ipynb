# %%
#W1A1
a = 7
b = 5
c = a - b
print(type(a), c, sep= '   ', end = '\t')
print(a)
#Gợi ý của ChatGPT
'''
1. a = 7

Gán giá trị 7 cho biến a.

Lúc này a = 7.

2. b = 5

Gán giá trị 5 cho biến b.

Lúc này b = 5.

3. c = a - b

Thực hiện phép trừ: a - b = 7 - 5 = 2.

Gán kết quả 2 vào biến c.

Lúc này c = 2.

4. print(c)

In giá trị của c ra màn hình.

Kết quả in ra là: 2
Tóm lại: Chương trình này tính hiệu của 7 và 5, rồi in ra kết quả.
👉 Kết quả cuối cùng là 2.
'''
# Out:
# <class 'int'>   2	7

# %%
#W1A2
city = "Ha Noi"
year = 2025
print("Thanh pho", city, "- Nam", year) #Thanh pho Ha Noi - Nam 2025
print(type(city))
print(type(False))
#Giải thích của AI
'''
1. city = "Ha Noi"

Tạo một biến tên city.

Gán giá trị chuỗi "Ha Noi" cho biến này.
👉 Lúc này city = "Ha Noi".

2. year = 2025

Tạo biến year.

Gán giá trị số nguyên 2025.
👉 Lúc này year = 2025.

3. print("Thanh pho", city, "- Nam", year)

Hàm print() in ra các đối số, ngăn cách nhau bằng dấu cách (mặc định sep = " ").

Các đối số lần lượt là:

Chuỗi "Thanh pho"

Biến city (có giá trị "Ha Noi")

Chuỗi "- Nam"

Biến year (có giá trị 2025)

Khi in, Python sẽ nối lại thành:

Thanh pho Ha Noi - Nam 2025

✅ Kết quả cuối cùng
Thanh pho Ha Noi - Nam 2025


👉 Sở dĩ có dấu cách giữa các phần là vì print mặc định thêm khoảng trắng giữa các đối số.
'''
# Out:
# Thanh pho Ha Noi - Nam 2025
# <class 'str'>
# <class 'bool'>

# %%
#W1A3
n = 4
t = 0
for i in range (1, n+1):
    t += i #t = t + i
print(t)
#Giải thích của AI
'''
Chương trình cộng dồn các số từ 1 đến n (ở đây n = 4) và in tổng.
Kết quả in ra: 10

Các trạng thái chính trong vòng lặp

i=1 → t = 0 + 1 = 1

i=2 → t = 1 + 2 = 3

i=3 → t = 3 + 3 = 6

i=4 → t = 6 + 4 = 10

Giải thích từng dòng (gọn)

1)n = 4 — gán biến n bằng 4 (số trên cùng cần cộng tới).

2)t = 0 — khởi tạo biến tích luỹ t bằng 0.

3)for i in range (1, n+1): — lặp i từ 1 đến n (vì range(1,n+1) tạo dãy 1,2,...,n).

4)t += i #t = t + i — mỗi lần lặp cộng giá trị i vào t (cộng dồn).

5)print(t) — in giá trị cuối cùng của t (tổng các số từ 1 đến n).
'''
# Out:
# 10

# %%
#W1A4
numbers = [1,2,3,4]
for x in numbers:
    if x % 2 == 0:
        print(x, "la so chan")
    else:
        print(x, "la so le")
  #Giải thích của AI
'''
Giải thích từng dòng:

numbers = [1,2,3,4] → Tạo list chứa 4 số.

for x in numbers: → Lặp qua từng phần tử x trong danh sách.

if x % 2 == 0: → Kiểm tra x chia hết cho 2.

Nếu đúng → in "x la so chan".

Nếu sai → in "x la so le".

Kết quả in ra:
1 la so le
2 la so chan
3 la so le
4 la so chan


👉 Vì 1 và 3 không chia hết cho 2 (số lẻ), còn 2 và 4 chia hết cho 2 (số chẵn).
'''
# Out:
# 1 la so le
# 2 la so chan
# 3 la so le
# 4 la so chan

# %%
#W1A5
animals = ["cat","dog","cat","bird"]
count = 0
for a in animals:
    count +=1
print("So phan tu trong danh sach la:", count)
#Giải thích của AI
'''
Giải thích từng dòng

1)animals = ["cat","dog","cat","bird"]

Tạo một danh sách gồm 4 phần tử: "cat", "dog", "cat", "bird".

2)count = 0

Biến đếm, khởi tạo bằng 0.

3)for a in animals:

Lặp qua từng phần tử trong danh sách animals.

Biến a sẽ lần lượt nhận giá trị "cat", "dog", "cat", "bird".

4)count +=1

Mỗi lần lặp, tăng biến count lên 1.

5)print("So phan tu trong danh sach la:", count)

In ra số phần tử sau khi đếm xong.

Diễn biến giá trị count

Bắt đầu: count = 0

Lặp 1: gặp "cat" → count = 1

Lặp 2: gặp "dog" → count = 2

Lặp 3: gặp "cat" → count = 3

Lặp 4: gặp "bird" → count = 4

✅ Kết quả in ra
So phan tu trong danh sach la: 4


👉 Vì danh sách có đúng 4 phần tử, dù có trùng "cat" hai lần thì vẫn được tính riêng.
'''

# %%
#W1A6

# %%
#W1A7
#Đoạn code đề bài:
'''
#W1A7
num = input("Nhap so: ")
if num %2 = 0:
    print("so chan")
else
    print("so le")
    '''
#Sửa lỗi với AI
num = int(input("Nhap so: "))
if num %2 == 0: #Lỗi sai toán tử
    print("so chan")
else:           #Sai cú pháp: thiếu dấu ":"
    print("so le")
# Out:
# Nhap so: 7
# so le

# %%
#W1A8
for i in range(3):
  print("AI đang học lần", i + 1)
print("Huấn luyện xong!")
#Giải thích của AI
'''
Cách hoạt động

range(3) sinh ra dãy số: 0, 1, 2.
→ Vòng lặp for chạy 3 lần, với i lần lượt là 0, 1, 2.

Trong mỗi lần lặp, in ra:

Lần 1 (i = 0): "AI đang học lần", 0 + 1 → 1

Lần 2 (i = 1): "AI đang học lần", 1 + 1 → 2

Lần 3 (i = 2): "AI đang học lần", 2 + 1 → 3

Sau khi thoát vòng lặp, in thêm dòng "Huấn luyện xong!".

✅ Kết quả in ra
AI đang học lần 1
AI đang học lần 2
AI đang học lần 3
Huấn luyện xong!


👉 Tóm gọn: Chương trình chạy 3 vòng để mô phỏng quá trình “AI học”, sau đó báo “đã học xong”.
'''
# Out:
# AI đang học lần 1
# AI đang học lần 2
# AI đang học lần 3
# Huấn luyện xong!

# %%
#W1A9
for x in ["cat", "dog", "fish"]:
  print("Dự đoán con vật:", x)
#Giải thích của AI
'''
✅ Kết quả: in ra 3 dòng

Dự đoán con vật: cat
Dự đoán con vật: dog
Dự đoán con vật: fish
'''
# Out:
# Dự đoán con vật: cat
# Dự đoán con vật: dog
# Dự đoán con vật: fish

# %%
#W1A10
'''
Đoạn code đề bài:

print "=== AI Prediction System ==="
print("1) Sentiment analysis"
print("2) Weather forecast"))
print('3) Exit'
print("Please choose an option:")
'''
#Sửa cú pháp với AI
print("=== AI Prediction System ===")
print("1) Sentiment analysis")
print("2) Weather forecast")
print("3) Exit")
print("Please choose an option:")
# Out:
# === AI Prediction System ===
# 1) Sentiment analysis
# 2) Weather forecast
# 3) Exit
# Please choose an option:
