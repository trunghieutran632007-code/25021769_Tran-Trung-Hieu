# %%
#W3A2
a = 10
b = 20
print(a,b)
a = a ^ b
b = a ^ b
a = a ^ b
print(a,b)
# Out:
# 10 20
# 20 10

# %%
#W3A3
n = int(input("Nhap mot so: "))
if (n & (n-1) == 0):
  print('n la luy thua cua 2')
else:
  print('n khong phai la luy thua cua 2')
# Out:
# Nhap mot so: -16
# n khong phai la luy thua cua 2

# %%
#W3A4
m = int(input("Nhap mot so: "))
n = int(input("Nhap mot so: "))
print(f'Ket qua lam tron xuong la {m//n}')
# Out:
# Nhap mot so: 5
# Nhap mot so: 2
# Ket qua lam tron len la 2

# %%
#W3A5
import math
m = int(input("Nhap mot so: "))
n = int(input("Nhap mot so: "))
print(f'Ket qua lam tron len la {math.ceil(m/n)}')
# Out:
# Nhap mot so: 5
# Nhap mot so: 2
# Ket qua lam tron len la 3

# %%
#W3A6
n = int(input('Nhap mot so: '))
if (n%2 == 0):
  print('Even')
else:
  print('Odd')
# Out:
# Nhap mot so: 7
# Odd

# %%
#W3A7
a, b = map(int, input('Nhap 2 so: ').split( ))
if (a < 0 and b < 0):
  print('YES')
else:
  print('NO')
# Out:
# Nhap 2 so: -9 -199
# YES

# %%
#W3A8
s1 = input()
s2 = input()
if(len(s1) > len(s2)):
  print('Yes')
else:
  print('No')
# Out:
# abcd
# abc
# Yes

# %%
#W3A9
a, b, c = map(int, input('Nhap 3 canh cua 1 tam giac: ').split())
if(a + b > c and a + c > b and b + c > a):
  print('Yes')
else:
  print('No')
# Out:
# Nhap 3 canh cua 1 tam giac: 3 4 5
# Yes

# %%
#W3A10
a, b, c, d = map(int, input('Nhap 4 so: ').split())
max
if(a > b and a > c and a > d):
  max = a
elif(b > a and b > c and b > d):
  max = b
elif(c > a and c > b and c > d):
  max = c
else:
  max = d
print(f'So lon nhat la {max}')
# Out:
# Nhap 4 so: 5 3 12 1
# So lon nhat la 12

# %%
#W3A11
a, b, c = map(int, input('Nhap 3 canh cua 1 tam giac: ').split())
if(a + b > c and a + c > b and b + c > a):
  if(a == b and a == c):
    print('Tam giac deu')
  elif(a == b or a == c or b == c):
    print('Tam giac can')
  else:
    print('Tam giac thuong')
else:
  print('Khong phai tam giac')
# Out:
# Nhap 3 canh cua 1 tam giac: 3 3 4
# Tam giac can

# %%
#W3A12
year = int(input('Nhap nam: '))
if((year % 4 == 0 and year % 100 != 0) or year % 400 == 0):
  print('Yes')
else:
  print('No')
# Out:
# Nhap nam: 1900
# No

# %%
#W3A14
a, b = map(int, input('Nhap 2 so thuc a, b cua phuong trinh ax + b = 0: ').split())
if a == 0:
    if b == 0:
        print("Vô số nghiệm")
    else:
        print("Vô nghiệm")
else:
    x = -b / a
    print(f"Nghiệm của phương trình là: {x:.2f}")
# Out:
# Nhap 2 so thuc a, b cua phuong trinh ax + b = 0: 21 6
# Nghiệm của phương trình là: -0.29

# %%
#W3A15
point = float(input('Nhap diem cua hs: '))
if point >= 8:
  print('Gioi')
elif (point >= 6.5 and point < 8):
  print('Kha')
elif (point >= 5 and point < 6.5):
  print('Trung binh')
else:
  print('Yeu')
# Out:
# Nhap diem cua hs: 7.9
# Kha

# %%
#W3A16
# Nhập số thực
x = float(input("Nhập một số thực: "))

# Lấy phần nguyên
nguyen = int(x)

# Tròn xuống
if x >= 0 or x == nguyen:
    tron_xuong = nguyen
else:
    tron_xuong = nguyen - 1

# Tròn lên (ceil)
if x >= 0 and x != nguyen:
    tron_len = nguyen + 1
else:
    tron_len = nguyen

# Tròn tới số nguyên gần nhất
phan_thap_phan = abs(x - nguyen) #lay trị tuyệt đối
if phan_thap_phan < 0.5:
    tron_gan = nguyen
elif x > 0:
    tron_gan = nguyen + 1
else:
    tron_gan = nguyen - 1

print(tron_len, tron_xuong, tron_gan)
# Out:
# Nhập một số thực: 7.8
# 8 7 8

# %%
#W3A17
a, b, c, d = map(int, input('Nhap 4 so: ').split())
if(b%a != 0):
  print('4 so theo thứ tự khong tao thanh cap so nhan voi cong boi nguyen')
else:
  k = b/a
  if(b*k == c):
    if(c*k == d):
      print('4 so theo thu tu tao thanh cap so nhan voi cong boi nguyen')
    else:
      print('4 so theo thu tu khong tao thanh cap so nhan voi cong boi nguyen')
  else:
    print('4 so theo thu tu khong tao thanh cap so nhan voi cong boi nguyen')
# Out:
# Nhap 4 so: 2 4 8 10
# 4 so theo thu tu khong tao thanh cap so nhan voi cong boi nguyen
